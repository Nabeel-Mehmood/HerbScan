# %%
from tensorflow.keras import backend as K
K.clear_session()

# %%
# !pip install rarfile
# Out:
# Collecting rarfile
#   Downloading rarfile-4.2-py3-none-any.whl.metadata (4.4 kB)
# Downloading rarfile-4.2-py3-none-any.whl (29 kB)
# Installing collected packages: rarfile
# Successfully installed rarfile-4.2

# %%
import os
import pandas as pd
import gdown
import rarfile
import shutil
from PIL import Image
# Download the RAR file
url = 'https://drive.google.com/uc?id=1uh58eeyRUqagxTSlnPyVDaVvoKYIuC95'
#https://drive.google.com/file/d/1g3EkPk0jPOVxHnsd4BqoRLZoznfFkdeC/view?usp=sharing
output_rar = '/content/Enhanced_Leguminosae_3C_Dataset.rar'
gdown.download(url, output_rar, quiet=False)
# Extract the RAR file
with rarfile.RarFile(output_rar, 'r') as rar_ref:
    rar_ref.extractall('/content')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1uh58eeyRUqagxTSlnPyVDaVvoKYIuC95
# To: /content/Enhanced_Leguminosae_3C_Dataset.rar
# 100%|██████████| 14.8M/14.8M [00:00<00:00, 63.3MB/s]

# %%
# Path to the extracted dataset folder

dataset = '/content/Enhanced_Leguminosae_3C_Dataset'

# %%
import os
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras import layers
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import (
    Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Add,
    GlobalAveragePooling2D, Flatten, Dense
)
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import KFold
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
)

# Directory for the dataset
data_dir = dataset

# Define the CNN architecture

# Initialize the InceptionV3 model without pre-trained weights
inception_model = InceptionV3(weights=None, include_top=False, input_shape=(299, 299, 3))
# Create a custom model for binary classification
model = models.Sequential()
# Add the InceptionV3 base
model.add(inception_model)

# Add global average pooling layer
model.add(layers.GlobalAveragePooling2D())

# Add a dense layer with 1024 units and ReLU activation
model.add(layers.Dense(1024, activation='relu'))

# Add a final output layer with 2 units and softmax activation for multi-class (2-class) classification
model.add(layers.Dense(4, activation='softmax'))  # 4 output neurons for 4 classes

# Print the model summary


# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# ImageDataGenerators
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Data generators for training, validation, and testing
train_generator = train_datagen.flow_from_directory(
    os.path.join(data_dir, 'Train'),
    target_size=(299, 299),
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_generator = val_datagen.flow_from_directory(
    os.path.join(data_dir, 'Validate'),
    target_size=(299, 299),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)

test_generator = test_datagen.flow_from_directory(
    os.path.join(data_dir, 'Test'),
    target_size=(299, 299),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)

# Training the model
history = model.fit(train_generator, epochs=60, validation_data=val_generator)

# Plot training results
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Helper function to evaluate the model on given test generator
def evaluate_model(test_generator, model, classes, title="Performance"):
    y_test_pred = model.predict(test_generator)
    y_test_pred = np.argmax(y_test_pred, axis=1)

    precision = precision_score(test_generator.labels, y_test_pred, average='weighted')
    recall = recall_score(test_generator.labels, y_test_pred, average='weighted')
    f1 = f1_score(test_generator.labels, y_test_pred, average='weighted')
    accuracy = accuracy_score(test_generator.labels, y_test_pred)

    print(f"\n{title}")
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)
    print("Accuracy:", accuracy)

    # Display the confusion matrix
    confusion = confusion_matrix(test_generator.labels, y_test_pred)
    confusion_df = pd.DataFrame(confusion, index=classes, columns=classes)
    print("Confusion Matrix:\n", confusion_df)

# Test the model on the test set
evaluate_model(test_generator, model, ['Acacia_Modesta', 'Albizia_Lebbeck', 'Bauhinia_Variegatav', 'Unknown'], title="Performance on Test Data")


# image form of confusion matrix
# Helper function to evaluate the model on given test generator
# def evaluate_model(test_generator, model, classes, title="Performance"):
#     y_test_pred = model.predict(test_generator)
#     y_test_pred = np.argmax(y_test_pred, axis=1)

#     precision = precision_score(test_generator.labels, y_test_pred, average='weighted')
#     recall = recall_score(test_generator.labels, y_test_pred, average='weighted')
#     f1 = f1_score(test_generator.labels, y_test_pred, average='weighted')
#     accuracy = accuracy_score(test_generator.labels, y_test_pred)

#     print(f"\n{title}")
#     print("Precision:", precision)
#     print("Recall:", recall)
#     print("F1 Score:", f1)
#     print("Accuracy:", accuracy)

#     # Display the confusion matrix
#     confusion = confusion_matrix(test_generator.labels, y_test_pred)
#     confusion_df = pd.DataFrame(confusion, index=classes, columns=classes)
#     print("Confusion Matrix:\n", confusion_df)

#     # Plot confusion matrix as heatmap
#     plt.figure(figsize=(8, 6))
#     sns.heatmap(confusion_df, annot=True, cmap='Blues', fmt='g')
#     plt.title(f'Confusion Matrix - {title}')
#     plt.ylabel('True Labels')
#     plt.xlabel('Predicted Labels')
#     plt.show()
# Out:
# Found 621 images belonging to 4 classes.
# Found 87 images belonging to 4 classes.
# Found 181 images belonging to 4 classes.
# Epoch 1/60
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 175s 4s/step - accuracy: 0.4782 - loss: 1.2195 - val_accuracy: 0.2644 - val_loss: 1.3865
# Epoch 2/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 388ms/step - accuracy: 0.7486 - loss: 0.5632 - val_accuracy: 0.2644 - val_loss: 1.5136
# Epoch 3/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 398ms/step - accuracy: 0.8205 - loss: 0.4423 - val_accuracy: 0.2644 - val_loss: 1.8809
# Epoch 4/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 389ms/step - accuracy: 0.8968 - loss: 0.2628 - val_accuracy: 0.2644 - val_loss: 2.3246
# Epoch 5/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 392ms/step - accuracy: 0.9166 - loss: 0.2120 - val_accuracy: 0.2644 - val_loss: 3.0250
# Epoch 6/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 397ms/step - accuracy: 0.9382 - loss: 0.1637 - val_accuracy: 0.2644 - val_loss: 4.0955
# Epoch 7/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 392ms/step - accuracy: 0.9227 - loss: 0.1845 - val_accuracy: 0.2644 - val_loss: 3.7697
# Epoch 8/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 399ms/step - accuracy: 0.9262 - loss: 0.1769 - val_accuracy: 0.2644 - val_loss: 3.8610
# Epoch 9/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 429ms/step - accuracy: 0.8988 - loss: 0.2974 - val_accuracy: 0.2644 - val_loss: 3.6780
# Epoch 10/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 406ms/step - accuracy: 0.9377 - loss: 0.1858 - val_accuracy: 0.2529 - val_loss: 2.8086
# Epoch 11/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 398ms/step - accuracy: 0.9465 - loss: 0.1595 - val_accuracy: 0.2529 - val_loss: 4.4828
# Epoch 12/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 412ms/step - accuracy: 0.9505 - loss: 0.1349 - val_accuracy: 0.1954 - val_loss: 3.5340
# Epoch 13/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 404ms/step - accuracy: 0.9768 - loss: 0.0831 - val_accuracy: 0.2529 - val_loss: 4.9101
# Epoch 14/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 398ms/step - accuracy: 0.9635 - loss: 0.0982 - val_accuracy: 0.4253 - val_loss: 3.5746
# Epoch 15/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 406ms/step - accuracy: 0.9549 - loss: 0.1511 - val_accuracy: 0.2529 - val_loss: 9.8625
# Epoch 16/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 408ms/step - accuracy: 0.9733 - loss: 0.0626 - val_accuracy: 0.2529 - val_loss: 17.6425
# Epoch 17/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 401ms/step - accuracy: 0.9817 - loss: 0.0770 - val_accuracy: 0.3448 - val_loss: 6.6775
# Epoch 18/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 408ms/step - accuracy: 0.9863 - loss: 0.0483 - val_accuracy: 0.4368 - val_loss: 6.4816
# Epoch 19/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 408ms/step - accuracy: 0.9860 - loss: 0.0454 - val_accuracy: 0.2529 - val_loss: 13.8271
# Epoch 20/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 431ms/step - accuracy: 0.9608 - loss: 0.1083 - val_accuracy: 0.3678 - val_loss: 4.4090
# Epoch 21/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 416ms/step - accuracy: 0.9801 - loss: 0.0584 - val_accuracy: 0.3793 - val_loss: 8.6945
# Epoch 22/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 419ms/step - accuracy: 0.9745 - loss: 0.1009 - val_accuracy: 0.2989 - val_loss: 12.0467
# Epoch 23/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 417ms/step - accuracy: 0.9766 - loss: 0.0500 - val_accuracy: 0.3218 - val_loss: 12.4263
# Epoch 24/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 411ms/step - accuracy: 0.9428 - loss: 0.1624 - val_accuracy: 0.3793 - val_loss: 11.1867
# Epoch 25/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 407ms/step - accuracy: 0.9328 - loss: 0.1943 - val_accuracy: 0.3218 - val_loss: 14.6017
# Epoch 26/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 426ms/step - accuracy: 0.9781 - loss: 0.0635 - val_accuracy: 0.5402 - val_loss: 3.0428
# Epoch 27/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 413ms/step - accuracy: 0.9830 - loss: 0.0543 - val_accuracy: 0.5172 - val_loss: 3.8631
# Epoch 28/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 427ms/step - accuracy: 0.9924 - loss: 0.0191 - val_accuracy: 0.6552 - val_loss: 1.5843
# Epoch 29/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 415ms/step - accuracy: 0.9762 - loss: 0.0881 - val_accuracy: 0.6552 - val_loss: 2.0613
# Epoch 30/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 416ms/step - accuracy: 0.9765 - loss: 0.0675 - val_accuracy: 0.6667 - val_loss: 1.5296
# Epoch 31/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 417ms/step - accuracy: 0.9593 - loss: 0.1141 - val_accuracy: 0.6897 - val_loss: 1.4780
# Epoch 32/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 428ms/step - accuracy: 0.9341 - loss: 0.1695 - val_accuracy: 0.7701 - val_loss: 0.9720
# Epoch 33/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 415ms/step - accuracy: 0.9660 - loss: 0.0868 - val_accuracy: 0.8046 - val_loss: 0.8535
# Epoch 34/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 413ms/step - accuracy: 0.9879 - loss: 0.0355 - val_accuracy: 0.8506 - val_loss: 0.5878
# Epoch 35/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 418ms/step - accuracy: 0.9664 - loss: 0.0531 - val_accuracy: 0.8506 - val_loss: 0.7820
# Epoch 36/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 428ms/step - accuracy: 0.9935 - loss: 0.0273 - val_accuracy: 0.8506 - val_loss: 1.1267
# Epoch 37/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 414ms/step - accuracy: 0.9887 - loss: 0.0315 - val_accuracy: 0.8161 - val_loss: 0.9711
# Epoch 38/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 412ms/step - accuracy: 0.9964 - loss: 0.0187 - val_accuracy: 0.7356 - val_loss: 1.6857
# Epoch 39/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 419ms/step - accuracy: 0.9843 - loss: 0.0478 - val_accuracy: 0.8391 - val_loss: 0.8691
# Epoch 40/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 417ms/step - accuracy: 0.9820 - loss: 0.0416 - val_accuracy: 0.7931 - val_loss: 1.1890
# Epoch 41/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 423ms/step - accuracy: 0.9941 - loss: 0.0358 - val_accuracy: 0.7241 - val_loss: 1.4409
# Epoch 42/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 415ms/step - accuracy: 0.9966 - loss: 0.0112 - val_accuracy: 0.8046 - val_loss: 0.9805
# Epoch 43/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 416ms/step - accuracy: 0.9737 - loss: 0.0838 - val_accuracy: 0.8506 - val_loss: 0.4969
# Epoch 44/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 419ms/step - accuracy: 0.9936 - loss: 0.0203 - val_accuracy: 0.9540 - val_loss: 0.1728
# Epoch 45/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 416ms/step - accuracy: 0.9925 - loss: 0.0300 - val_accuracy: 0.7701 - val_loss: 1.1512
# Epoch 46/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 426ms/step - accuracy: 0.9950 - loss: 0.0159 - val_accuracy: 0.8161 - val_loss: 0.5824
# Epoch 47/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 417ms/step - accuracy: 0.9977 - loss: 0.0137 - val_accuracy: 0.8161 - val_loss: 0.6170
# Epoch 48/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 421ms/step - accuracy: 0.9945 - loss: 0.0146 - val_accuracy: 0.6782 - val_loss: 1.3558
# Epoch 49/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 418ms/step - accuracy: 0.9895 - loss: 0.0319 - val_accuracy: 0.6322 - val_loss: 1.6812
# Epoch 50/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 429ms/step - accuracy: 0.9929 - loss: 0.0373 - val_accuracy: 0.8276 - val_loss: 0.8410
# Epoch 51/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 417ms/step - accuracy: 0.9991 - loss: 0.0042 - val_accuracy: 0.8161 - val_loss: 0.8772
# Epoch 52/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 419ms/step - accuracy: 0.9963 - loss: 0.0102 - val_accuracy: 0.7241 - val_loss: 1.1351
# Epoch 53/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 441ms/step - accuracy: 0.9848 - loss: 0.0572 - val_accuracy: 0.7931 - val_loss: 0.6925
# Epoch 54/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 423ms/step - accuracy: 0.9896 - loss: 0.0312 - val_accuracy: 0.7701 - val_loss: 0.8537
# Epoch 55/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 415ms/step - accuracy: 0.9962 - loss: 0.0294 - val_accuracy: 0.8966 - val_loss: 0.3652
# Epoch 56/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 418ms/step - accuracy: 0.9963 - loss: 0.0150 - val_accuracy: 0.8506 - val_loss: 0.5869
# Epoch 57/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 422ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.8736 - val_loss: 0.8012
# Epoch 58/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 417ms/step - accuracy: 0.9979 - loss: 0.0090 - val_accuracy: 0.8966 - val_loss: 0.4596
# Epoch 59/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 416ms/step - accuracy: 0.9960 - loss: 0.0119 - val_accuracy: 0.9310 - val_loss: 0.2983
# Epoch 60/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 416ms/step - accuracy: 0.9971 - loss: 0.0118 - val_accuracy: 0.8621 - val_loss: 0.5381
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step
#
# Performance on Test Data
# Precision: 0.8706644373364351
# Recall: 0.8674033149171271
# F1 Score: 0.8679444899539782
# Accuracy: 0.8674033149171271
# Confusion Matrix:
#                       Acacia_Modesta  Albizia_Lebbeck  Bauhinia_Variegatav  \
# Acacia_Modesta                   38                3                    0
# Albizia_Lebbeck                   3               35                    0
# Bauhinia_Variegatav               2                0                   43
# Unknown                           5                0                    2
#
#                      Unknown
# Acacia_Modesta             4
# Albizia_Lebbeck            5
# Bauhinia_Variegatav        0
# Unknown                   41

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.models import load_model
model.save('/content/drive/MyDrive/FYP/CNN models/For Enhanced_Dataset/AugmentedandEnhanced_Leguminosae_3C_classification_Inception_V3 (3).ipynb')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2b06631dcbd6> in <cell line: 2>()
#       1 from tensorflow.keras.models import load_model
# ----> 2 model.save('/content/drive/MyDrive/FYP/CNN models/For Enhanced_Dataset/AugmentedandEnhanced_Leguminosae_3C_classification_Inception_V3 (3).ipynb')
#
# NameError: name 'model' is not defined
